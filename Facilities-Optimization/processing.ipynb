# %%
import pandas as pd # type: ignore

lat_long_dataset = pd.read_csv("Book2.csv")
comp_dataset = pd.read_csv("ALLCENSUSTRACTS.csv")

# %%
lat_long_dataset
# Out:
#       USPS  CensusTract       ALAND  AWATER  ALAND_SQMI  AWATER_SQMI  \
# 0       AL   1001020100   9817813.0   28435       3.791        0.011
# 1       AL   1001020200   3325680.0    5669       1.284        0.002
# 2       AL   1001020300   5349273.0    9054       2.065        0.003
# 3       AL   1001020400   6384276.0    8408       2.465        0.003
# 4       AL   1001020500  11408866.0   43534       4.405        0.017
# ...    ...          ...         ...     ...         ...          ...
# 73996   PR  72153750501   1820185.0       0       0.703        0.000
# 73997   PR  72153750502    689930.0       0       0.266        0.000
# 73998   PR  72153750503   3298433.0    1952       1.274        0.001
# 73999   PR  72153750601  10987037.0    4527       4.242        0.002
# 74000   PR  72153750602  17520483.0  252953       6.765        0.098
#
#         INTPTLAT  \
# 0      32.481959
# 1      32.475758
# 2      32.474024
# 3      32.471030
# 4      32.458922
# ...          ...
# ...

# %%
merged_dataset = pd.merge(lat_long_dataset, comp_dataset, on="CensusTract", how="inner")
merged_dataset
# Out:
#       USPS  CensusTract         ALAND   AWATER  ALAND_SQMI  AWATER_SQMI  \
# 0       AL   1001020100  9.817813e+06    28435       3.791        0.011
# 1       AL   1001020200  3.325680e+06     5669       1.284        0.002
# 2       AL   1001020300  5.349273e+06     9054       2.065        0.003
# 3       AL   1001020400  6.384276e+06     8408       2.465        0.003
# 4       AL   1001020500  1.140887e+07    43534       4.405        0.017
# ...    ...          ...           ...      ...         ...          ...
# 72526   WY  56043000200  5.780716e+09  9742603    2231.947        3.762
# 72527   WY  56043000301  1.993203e+06        0       0.770        0.000
# 72528   WY  56043000302  1.542921e+07   687001       5.957        0.265
# 72529   WY  56045951100  6.100010e+09  5041727    2355.227        1.947
# 72530   WY  56045951300  1.107940e+08   183772      42.778        0.071
#
#         INTPTLAT  \
# 0      32.481959
# 1      32.475758
# 2      32.474024
# 3      32.471030
# ...

# %%
merged_dataset.to_csv("merged_dataset.csv")
